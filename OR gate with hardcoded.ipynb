# %% [markdown]
# <a href="https://colab.research.google.com/github/mishti127/Deep-learning/blob/main/OR%20gate%20with%20hardcoded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OR Gate using a Single Neuron (Perceptron)

import numpy as np
def step_activation(x):
    if x >= 0:
        return 1
    else:
        return 0
def neuron(inputs, weights, bias):

    inputs = np.array(inputs)
    weights = np.array(weights)
    weighted_sum = np.dot(inputs, weights) + bias
    output = step_activation(weighted_sum)
    return weighted_sum, output
weights = [1, 1]
bias = -0.5
dataset = [
    [0,0],
    [0,1],
    [1,0],
    [1,1]
]
print("OR Gate using Perceptron")
print("--------------------------------------")
print("Weights:", weights)
print("Bias:", bias)

print("\nTruth Table")
print("x1  x2  Weighted Sum  Output")
for data in dataset:
    z, result = neuron(data, weights, bias)
    print(data[0], " ", data[1], "     ",z, "        ", result)
# Out:
# OR Gate using Perceptron
# --------------------------------------
# Weights: [1, 1]
# Bias: -0.5
#
# Truth Table
# x1  x2  Weighted Sum  Output
# 0   0       -0.5          0
# 0   1       0.5          1
# 1   0       0.5          1
# 1   1       1.5          1
